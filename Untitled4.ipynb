# %%
import numpy as np 
import pandas as pd 
import xgboost as xgb
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.metrics import mean_squared_error
from datetime import datetime, timedelta

# %%
ev=pd.read_csv("AEP_hourly.csv")

# %%
ev
# Out:
#                    Datetime   AEP_MW
# 0       2004-12-31 01:00:00  13478.0
# 1       2004-12-31 02:00:00  12865.0
# 2       2004-12-31 03:00:00  12577.0
# 3       2004-12-31 04:00:00  12517.0
# 4       2004-12-31 05:00:00  12670.0
# ...                     ...      ...
# 121268  2018-01-01 20:00:00  21089.0
# 121269  2018-01-01 21:00:00  20999.0
# 121270  2018-01-01 22:00:00  20820.0
# 121271  2018-01-01 23:00:00  20415.0
# 121272  2018-01-02 00:00:00  19993.0
#
# [121273 rows x 2 columns]

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
ev.isnull().sum()
# Out:
# Datetime    0
# AEP_MW      0
# dtype: int64

# %%
ev["Datetime"]= pd.to_datetime(ev["Datetime"])

# %%
sns.lineplot(data=ev,x="Datetime",y="AEP_MW")
# Out:
# <Axes: xlabel='Datetime', ylabel='AEP_MW'>

# %%
ev.head()
# Out:
#              Datetime   AEP_MW
# 0 2004-12-31 01:00:00  13478.0
# 1 2004-12-31 02:00:00  12865.0
# 2 2004-12-31 03:00:00  12577.0
# 3 2004-12-31 04:00:00  12517.0
# 4 2004-12-31 05:00:00  12670.0

# %%
ev=ev.set_index("Datetime")

# %%
ev
# Out:
#                       AEP_MW
# Datetime
# 2004-12-31 01:00:00  13478.0
# 2004-12-31 02:00:00  12865.0
# 2004-12-31 03:00:00  12577.0
# 2004-12-31 04:00:00  12517.0
# 2004-12-31 05:00:00  12670.0
# ...                      ...
# 2018-01-01 20:00:00  21089.0
# 2018-01-01 21:00:00  20999.0
# 2018-01-01 22:00:00  20820.0
# 2018-01-01 23:00:00  20415.0
# 2018-01-02 00:00:00  19993.0
#
# [121273 rows x 1 columns]

# %%
plt.figure(figsize=(16,9))
sns.lineplot(data=ev,x="Datetime",y="AEP_MW")
plt.title("Electric_Production_Rate")
# Out:
# Text(0.5, 1.0, 'Electric_Production_Rate')

# %%
def feature_selection(df):
    df["hour"]=df.index.hour
    df["day_of_week"]=df.index.dayofweek
    df["quarter"]=df.index.quarter
    df["month"]=df.index.month
    df["year"]=df.index.year
    df["day_of_year"]=df.index.dayofyear
    return df 

ev=feature_selection(ev)
test=ev[ev.index>="01-01-2015"]
train=ev[ev.index<"01-01-2015"]

# %%
fig=plt.figure(figsize=(16,9))
ax=fig.add_axes([0,0,.8,.8])
ax.plot(train,color="blue",ls="-",marker="o",label="Train", mfc = 'r')
ax.plot(test,color="green",ls="-",marker="o",label="Test", mfc = 'y')
plt.title("Train / Test --- Split")
plt.xlabel("Date")
plt.ylabel("Electric_Production")
# Out:
# Text(0, 0.5, 'Electric_Production')

# %%
ev
# Out:
#                       AEP_MW  hour  day_of_week  quarter  month  year  \
# Datetime
# 2004-12-31 01:00:00  13478.0     1            4        4     12  2004
# 2004-12-31 02:00:00  12865.0     2            4        4     12  2004
# 2004-12-31 03:00:00  12577.0     3            4        4     12  2004
# 2004-12-31 04:00:00  12517.0     4            4        4     12  2004
# 2004-12-31 05:00:00  12670.0     5            4        4     12  2004
# ...                      ...   ...          ...      ...    ...   ...
# 2018-01-01 20:00:00  21089.0    20            0        1      1  2018
# 2018-01-01 21:00:00  20999.0    21            0        1      1  2018
# 2018-01-01 22:00:00  20820.0    22            0        1      1  2018
# 2018-01-01 23:00:00  20415.0    23            0        1      1  2018
# 2018-01-02 00:00:00  19993.0     0            1        1      1  2018
#
#                      day_of_year
# Datetime
# 2004-12-31 01:00:00          366
# 2004-12-31 02:00:00          366
# ...

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=ev,x="month",y="AEP_MW",hue="month",palette="viridis")
plt.legend(loc=(1.03,0.8))

# %%
plt.figure(figsize=(12,9))
sns.boxplot(data=ev,x="hour",y="AEP_MW",hue="hour")
plt.legend(loc=(1.03,0.8))

# %%
x_train=train.drop("AEP_MW",axis=1)
y_train=train[["AEP_MW"]]

x_test=test.drop("AEP_MW",axis=1)
y_test=test[["AEP_MW"]]

# %%
xgb_reg=xgb.XGBRegressor(n_estimators=1000,early_stopping_rounds=50,learning_rate=0.01)

# %%
xgb_reg.fit(x_train,y_train,eval_set=[(x_train,y_train),(x_test,y_test)], verbose=100)
# Out:
# [0]	validation_0-rmse:2557.05852	validation_1-rmse:2669.66874
# [100]	validation_0-rmse:1667.99304	validation_1-rmse:1906.43321
# [200]	validation_0-rmse:1388.41609	validation_1-rmse:1728.03964
# [300]	validation_0-rmse:1260.06288	validation_1-rmse:1670.93868
# [400]	validation_0-rmse:1170.54347	validation_1-rmse:1651.83339
# [500]	validation_0-rmse:1113.48343	validation_1-rmse:1644.49126
# [545]	validation_0-rmse:1091.20163	validation_1-rmse:1647.88201
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
# ...

# %%
y_pred=xgb_reg.predict(x_test)

# %%
fig=plt.figure(figsize=(16,9))
plt.plot(ev.index,ev["AEP_MW"])
plt.plot(x_test.index,y_pred)

# %%
score=np.sqrt(mean_squared_error(y_test,y_pred))

# %%
score
# Out:
# 1644.3873400386153

# %%
import pandas as pd
from datetime import timedelta, datetime
import matplotlib.pyplot as plt


last_date = ev.index[-1]


days_to_generate = 365
hours_to_generate = days_to_generate * 24  

all_dates = [last_date + timedelta(hours=i) for i in range(1, hours_to_generate + 1)]

# Create DataFrame from future dates
df = pd.DataFrame(all_dates, columns=["date"])
df = df.set_index("date")


def feature_selection(df):
    df["hour"] = df.index.hour
    df["day_of_week"] = df.index.dayofweek
    df["quarter"] = df.index.quarter
    df["month"] = df.index.month
    df["year"] = df.index.year
    df["day_of_year"] = df.index.dayofyear
    return df

df = feature_selection(df)

# Fit the XGBoost model on the existing data (X, Y)
X = ev.drop("AEP_MW", axis=1)
Y = ev["AEP_MW"]

xgb_reg = xgb.XGBRegressor(n_estimators=1000, learning_rate=0.01)
xgb_reg.fit(X, Y, verbose=100)


y_pred = xgb_reg.predict(df)


fig = plt.figure(figsize=(16, 9))
plt.plot(ev.index, ev["AEP_MW"], label="Actual Data")   # Plot existing data
plt.plot(df.index, y_pred, label="Predicted Future", color="orange")  # Plot future predictions
plt.legend()
plt.show()
